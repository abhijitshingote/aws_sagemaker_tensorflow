# %%
import tensorflow as tf
import numpy as np
import pandas as pd
# import matplotlib.pyplot as plt
from sagemaker.tensorflow import TensorFlow

# %%
import sagemaker
sess=sagemaker.Session()
role='arn:aws:iam::032934527328:role/service-role/AmazonSageMaker-ExecutionRole-20201014T214516'
prefix='cats_dogs_prediction'
# training_input_path   = sess.upload_data('cats_n_dogs', key_prefix=prefix)

# %%
# training_input_path
training_input_path='s3://sagemaker-us-east-1-032934527328/cats_dogs_prediction'

# %%
hyperparameters={'epochs':5}

# %%
estimator=TensorFlow(
    entry_point= "cats_dogs_sagemaker_train_script.py",             # Your entry script
    role=role,
    framework_version="2.0.0",               # TensorFlow's version
    py_version='py3',
    train_instance_count=1,                   # "The number of GPUs instances to use"
#     train_instance_type='ml.c5.2xlarge',
    train_instance_type='local',
    hyperparameters=hyperparameters,
)
# Out:
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
estimator.fit({'train':training_input_path})
# Out:
# Creating tmp8btae90q_algo-1-izc8l_1 ...
# Attaching to tmp8btae90q_algo-1-izc8l_12mdone
# algo-1-izc8l_1  | 2020-11-08 05:18:26,364 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# algo-1-izc8l_1  | 2020-11-08 05:18:26,380 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-izc8l_1  | 2020-11-08 05:18:26,981 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-izc8l_1  | 2020-11-08 05:18:27,020 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-izc8l_1  | 2020-11-08 05:18:27,046 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-izc8l_1  | 2020-11-08 05:18:27,060 sagemaker-containers INFO     Invoking user script
# algo-1-izc8l_1  |
# algo-1-izc8l_1  | Training Env:
# algo-1-izc8l_1  |
# algo-1-izc8l_1  | {
# algo-1-izc8l_1  |     "additional_framework_parameters": {},
# ...
